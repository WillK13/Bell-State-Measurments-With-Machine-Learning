# %%
# Imports 
import numpy as np
import pandas as pd
from pandas import DataFrame, Series

# Plots
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

# %matplotlib inline

from sklearn import linear_model
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
X =  iris.data

Y = iris.target

# %%
iris_data = DataFrame(X, columns=['X', 'CNOT', 'Z', 'Y'])

# %%
iris_target = DataFrame(Y, columns=['H'])

# %%
def flower(num):
    if num == 0:
        return 'B1'
    elif num == 1:
        return 'B2'
    elif num == 2:
        return 'B3'
    else:
        return 'B4'

# %%
iris_target['Species'] =iris_target['H'].apply(flower)

# %%
iris = pd.concat([iris_data,iris_target], axis = 1)

# %%
sns.pairplot(iris, hue='Species', size=2)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.factorplot('X',kind = 'count', data = iris, hue = "Species", size = 10)
